# %%
type(1)
# Out:
# int

# %%
import sys
print(sys.version)
print(sys.executable)
print(sys.path)
print(sys.platform)
print(sys.prefix)
print(sys.version_info)
print(sys.implementation)
print(sys.api_version)
print(sys.builtin_module_names)
print(sys.byteorder)
print(sys.copyright)    
print(sys.float_info)
# Out:
# 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)]
# c:\Users\91960\AppData\Local\Programs\Python\Python311\python.exe
# ['c:\\Users\\91960\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'c:\\Users\\91960\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'c:\\Users\\91960\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'c:\\Users\\91960\\AppData\\Local\\Programs\\Python\\Python311', '', 'C:\\Users\\91960\\AppData\\Roaming\\Python\\Python311\\site-packages', 'C:\\Users\\91960\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32', 'C:\\Users\\91960\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\91960\\AppData\\Roaming\\Python\\Python311\\site-packages\\Pythonwin', 'c:\\Users\\91960\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages']
# win32
# c:\Users\91960\AppData\Local\Programs\Python\Python311
# sys.version_info(major=3, minor=11, micro=5, releaselevel='final', serial=0)
# namespace(name='cpython', cache_tag='cpython-311', version=sys.version_info(major=3, minor=11, micro=5, releaselevel='final', serial=0), hexversion=51054064)
# 1013
# ('_abc', '_ast', '_bisect', '_blake2', '_codecs', '_codecs_cn', '_codecs_hk', '_codecs_iso2022', '_codecs_jp', '_codecs_kr', '_codecs_tw', '_collections', '_contextvars', '_csv', '_datetime', '_functools', '_heapq', '_imp', '_io', '_json', '_locale', '_lsprof', '_md5', '_multibytecodec', '_opcode', '_operator', '_pickle', '_random', '_sha1', '_sha256', '_sha3', '_sha512', '_signal', '_sre', '_stat', '_statistics', '_string', '_struct', '_symtable', '_thread', '_tokenize', '_tracemalloc', '_typing', '_warnings', '_weakref', '_winapi', '_xxsubinterpreters', 'array', 'atexit', 'audioop', 'binascii', 'builtins', 'cmath', 'errno', 'faulthandler', 'gc', 'itertools', 'marshal', 'math', 'mmap', 'msvcrt', 'nt', 'sys', 'time', 'winreg', 'xxsubtype', 'zlib')
# little
# Copyright (c) 2001-2023 Python Software Foundation.
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved.
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
float('1.2')
# Out:
# 1.2

# %%
str(1.2)
# Out:
# '1.2'

# %%
type(True)
# Out:
# bool

# %%
float(True)
# Out:
# 1.0

# %%
int(3.99)
# Out:
# 3

# %%
str="data science"
str.title()
# Out:
# 'Data Science'

# %%
 print("Python is \"awesome\"")
# Out:
# Python is "awesome"
